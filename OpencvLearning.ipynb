# %%
import ImageOperator
import matplotlib.pyplot as plt

# %%
IOperator = ImageOperator.ImageOperator('Image/test.jpg')
# Out:
# 4.6.0

# %%
args = [(250, 250), 100, (255, 0, 0)]
img = IOperator.putShape('circle', args, inplace = False)
plt.imshow(img)
plt.show()

# %%
args = [(250, 250), (800,600), (255, 0, 0)]
img = IOperator.putShape('rectangle', args, inplace = False)
plt.imshow(img)
plt.show()

# %%
IOperator.showImageNotebook()

# %%
import qt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-54fa7e43bda8> in <module>
# ----> 1 import qt
#
# ModuleNotFoundError: No module named 'qt'

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('Image/test.jpg')


args = [img.copy()] + args
expression = '''
cv2.circle(*args)
'''

# %%
dimg = eval(expression)

# %%
plt.imshow(dimg)
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
import VideoOperator

# %%
vc = VideoOperator.VideoOperator('Video/Cat.mp4')

# %%
# vc.createFramesfromVideo('Video/Frames')

# %%
vc.concatenateVids('Video', '/home/adithya/imp_repos/opencvLearning/Video/NewVid.mp4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-05d03bb479cd> in <module>
# ----> 1 vc.concatenateVids('Video', '/home/adithya/imp_repos/opencvLearning/Video/NewVid.mp4')
#
# ~/imp_repos/opencvLearning/VideoOperator.py in concatenateVids(self, vidPath, savePath)
#      35         videos = []
#      36         for t in types:
# ---> 37             videos.extend(glob.glob(os.path.join(vidpath, t)))
#      38
#      39         print(videos)
#
# NameError: name 'vidpath' is not defined
